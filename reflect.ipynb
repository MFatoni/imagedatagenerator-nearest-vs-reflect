# %%
plt.show()

# %%
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Train on 1599 samples, validate on 400 samples
# Epoch 1/30
# 1599/1599 [==============================] - 24s 15ms/sample - loss: 1.4142 - accuracy: 0.2802 - val_loss: 1.3511 - val_accuracy: 0.4225
# Epoch 2/30
# 1599/1599 [==============================] - 9s 6ms/sample - loss: 1.2338 - accuracy: 0.4315 - val_loss: 1.0060 - val_accuracy: 0.5625
# Epoch 3/30
# 1599/1599 [==============================] - 10s 6ms/sample - loss: 0.9475 - accuracy: 0.5566 - val_loss: 0.7993 - val_accuracy: 0.6350
# Epoch 4/30
# 1599/1599 [==============================] - 12s 7ms/sample - loss: 0.7955 - accuracy: 0.6210 - val_loss: 0.7211 - val_accuracy: 0.6900
# Epoch 5/30
# 1599/1599 [==============================] - 12s 7ms/sample - loss: 0.6752 - accuracy: 0.7017 - val_loss: 0.5889 - val_accuracy: 0.7450
# Epoch 6/30
# 1599/1599 [==============================] - 7s 5ms/sample - loss: 0.5807 - accuracy: 0.7448 - val_loss: 0.5385 - val_accuracy: 0.7675
# Epoch 7/30
# ...

# %%
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
print(classification_report(y_test_, y_pred, target_names=mapping.values()))
# Out:
#               precision    recall  f1-score   support
#
#     aglonema       0.93      0.94      0.93       105
#       bonsai       0.95      0.92      0.94       102
#     matahari       0.98      0.99      0.98        97
#    kalamansi       0.99      0.99      0.99        96
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.96      0.96       400
# weighted avg       0.96      0.96      0.96       400

# %%
plot_confusion_matrix(cnf_matrix, classes=['aglonema','bonsai','matahari','kalamansi'],title='Confusion matrix')
# Out:
# Confusion matrix, without normalization

# %%
plot_confusion_matrix(cnf_matrix, classes=['aglonema','bonsai','matahari','kalamansi'],title='Confusion matrix',normalize=True)
# Out:
# Normalized confusion matrix
